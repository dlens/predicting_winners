# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('footballStats.xlsx')

df
# Out:
#      Week  Day       Date    Time                 Winner  \
# 0       1  Thu 2023-09-07  8:20PM          Detroit Lions
# 1       1  Sun 2023-09-10  1:00PM        Atlanta Falcons
# 2       1  Sun 2023-09-10  1:00PM       Cleveland Browns
# 3       1  Sun 2023-09-10  1:00PM   Jacksonville Jaguars
# 4       1  Sun 2023-09-10  1:00PM  Washington Commanders
# ..    ...  ...        ...     ...                    ...
# 267    18  Sun 2024-01-07  4:25PM      Las Vegas Raiders
# 268    18  Sun 2024-01-07  4:25PM     Kansas City Chiefs
# 269    18  Sun 2024-01-07  4:25PM        New York Giants
# 270    18  Sun 2024-01-07  4:25PM       Los Angeles Rams
# 271    18  Sun 2024-01-07  8:20PM          Buffalo Bills
#
#                     Loser  PtsW  PtsL  YdsW  TOW  YdsL  TOL
# 0      Kansas City Chiefs    21    20   368    1   316    1
# 1       Carolina Panthers    24    10   221    0   281    3
# 2      Cincinnati Bengals    24     3   350    2   142    0
# 3      Indianapolis Colts    31    21   342    2   280    3
# 4       Arizona Cardinals    20    16   248    3   210    2
# ..                    ...   ...   ...   ...  ...   ...  ...
# 267        Denver Broncos    27    14   359    0   286    1
# 268  Los Angeles Chargers    13    12   268    1   353    1
# 269   Philadelphia Eagles    27    10   415    1   299    4
# 270   San Francisco 49ers    21    20   258    1   300    1
# 271        Miami Dolphins    21    14   473    3   275    2
#
# [272 rows x 12 columns]

# %%
plt.bar(df['Winner'], df['PtsW']) 
plt.xlabel("Winning team") 
plt.ylabel("Pts Scored") 
plt.title("Pts Scored by winning team") 
plt.show()

# %%
plt.bar(df['Week'], df['PtsW']-df['PtsL'])
plt.xlabel("Week") 
plt.xticks(range(1,19))
plt.ylabel("Pts diff") 
plt.title("random test") 
plt.show()

# %%
df['PtsL']
# Out:
# 0      20
# 1      10
# 2       3
# 3      21
# 4      16
#        ..
# 267    14
# 268    12
# 269    10
# 270    20
# 271    14
# Name: PtsL, Length: 272, dtype: int64

# %%
df.__getitem__('PtsL')
# Out:
# 0      20
# 1      10
# 2       3
# 3      21
# 4      16
#        ..
# 267    14
# 268    12
# 269    10
# 270    20
# 271    14
# Name: PtsL, Length: 272, dtype: int64
